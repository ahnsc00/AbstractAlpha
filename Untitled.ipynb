# %%
import os
import pandas as pd
from gym_trading_env.downloader import download
import datetime
import gymnasium as gym
import gym_trading_env
import pandas as pd
import matplotlib.pyplot as plt

# %%
download(exchange_names=["binance"],
         symbols=["BTC/USDT"],
         timeframe="4h",
         dir="data",
         since=datetime.datetime(year=2018, month=1, day=1))
# Out:
# BTC/USDT downloaded from binance and stored at data/binance-BTCUSDT-4h.pkl

# %%
def coin_load_data():
    # 데이터 로드
    btc_df = pd.read_pickle("./data/binance-BTCUSDT-4h.pkl")
    
    # 인덱스를 datetime으로 변환
    btc_df.index = pd.to_datetime(btc_df.index, errors='coerce')  # 'coerce'로 변환 불가능한 값을 NaT로 설정
    btc_df.index.rename('date', inplace=True)  # 인덱스 이름을 'date'로 설정

    def create_time_series_df(df):
        n = 100
        result = []

        dates = df.index  # 인덱스에서 직접 접근
        closes = df['close'].values

        # 첫 100개를 포함한 시퀀스 생성
        for i in range(len(df) - n + 1):
            date_slice = dates[i:i + n]
            close_slice = closes[i:i + n]
            if len(close_slice) == n:
                result.append([date_slice[-1].strftime('%Y%m%d')] + close_slice.tolist())  # 마지막 날짜만 저장

        # 데이터프레임 생성
        columns = ['date'] + [f'close_{i + 1}' for i in range(n)]
        time_series_df = pd.DataFrame(result, columns=columns)

        # 데이터 부족 시 추가 처리 불필요
        return time_series_df.astype(float, errors='ignore')

    # 시계열 데이터 생성
    df = create_time_series_df(btc_df)
    
    # 학습 데이터 준비
    coin_training_data = df.drop(columns=['date']).values
    
    # 차트 데이터 준비
    coin_chart_data = btc_df.copy()
    coin_chart_data['date'] = coin_chart_data.index.strftime('%Y%m%d')  # 인덱스를 문자열로 변환
    coin_chart_data = coin_chart_data[['date', 'open', 'high', 'low', 'close', 'volume']]
    
    # training_data를 DataFrame으로 변환
    columns = [f'close_{i + 1}' for i in range(coin_training_data.shape[1])]
    coin_training_data = pd.DataFrame(coin_training_data, columns=columns)

    return coin_chart_data, coin_training_data

# %%
chart_data, training_data = coin_load_data()

# %%
 training_data
# Out:
#           close   close_2   close_3   close_4   close_5   close_6   close_7  \
# 0      13780.16  13716.36  13410.03  13570.35  13220.56  13247.00  13240.37
# 1      13716.36  13410.03  13570.35  13220.56  13247.00  13240.37  13380.00
# 2      13410.03  13570.35  13220.56  13247.00  13240.37  13380.00  13353.78
# 3      13570.35  13220.56  13247.00  13240.37  13380.00  13353.78  13343.00
# 4      13220.56  13247.00  13240.37  13380.00  13353.78  13343.00  13490.00
# ...         ...       ...       ...       ...       ...       ...       ...
# 14969  69813.91  69608.00  69393.17  69510.00  69374.74  68379.89  68397.42
# 14970  69608.00  69393.17  69510.00  69374.74  68379.89  68397.42  68358.86
# 14971  69393.17  69510.00  69374.74  68379.89  68397.42  68358.86  68090.90
# 14972  69510.00  69374.74  68379.89  68397.42  68358.86  68090.90  68679.00
# 14973  69374.74  68379.89  68397.42  68358.86  68090.90  68679.00  68775.99
#
#         close_8   close_9  close_10  ...  close_91  close_92  close_93  \
# 0      13380.00  13353.78  13343.00  ...  13760.00  13539.93  12828.99
# 1      13353.78  13343.00  13490.00  ...  13539.93  12828.99  12347.32
# 2      13343.00  13490.00  13690.03  ...  12828.99  12347.32  12127.16
# 3      13490.00  13690.03  14732.75  ...  12347.32  12127.16  11964.02
# 4      13690.03  14732.75  14675.11  ...  12127.16  11964.02  11064.52
# ...         ...       ...       ...  ...       ...       ...       ...
# 14969  68358.86  68090.90  68679.00  ...  90550.80  90684.19  90260.01
# 14970  68090.90  68679.00  68775.99  ...  90684.19  90260.01  90044.00
# 14971  68679.00  68775.99  69047.86  ...  90260.01  90044.00  89855.99
# 14972  68775.99  69047.86  68618.00  ...  90044.00  89855.99  90668.58
# 14973  69047.86  68618.00  68792.71  ...  89855.99  90668.58  91719.90
#
#        close_94  close_95  close_96  close_97  close_98  close_99  close_100
# 0      12347.32  12127.16  11964.02  11064.52  10900.00  10415.99   10765.01
# 1      12127.16  11964.02  11064.52  10900.00  10415.99  10765.01    9808.14
# 2      11964.02  11064.52  10900.00  10415.99  10765.01   9808.14    9227.47
# 3      11064.52  10900.00  10415.99  10765.01   9808.14   9227.47   10390.00
# 4      10900.00  10415.99  10765.01   9808.14   9227.47  10390.00   10988.79
# ...         ...       ...       ...       ...       ...       ...        ...
# 14969  90044.00  89855.99  90668.58  91719.90  90275.13  92309.51   90608.26
# 14970  89855.99  90668.58  91719.90  90275.13  92309.51  90608.26   90464.08
# 14971  90668.58  91719.90  90275.13  92309.51  90608.26  90464.08   91428.00
# 14972  91719.90  90275.13  92309.51  90608.26  90464.08  91428.00   91620.01
# 14973  90275.13  92309.51  90608.26  90464.08  91428.00  91620.01   91569.97
#
# [14974 rows x 100 columns]

# %%
training_data.rename(columns={'close_1': 'close'}, inplace=True)

# %%
# 거래 환경 초기화
env = gym.make("TradingEnv",
               name="BTCUSD",
               df=training_data,
               positions=[-1, 0, 1],
               trading_fees=0.01/100,
               borrow_interest_rate=0.0003/100)

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# 벡터화된 환경으로 포장
vec_env = DummyVecEnv([lambda: env])

# PPO 에이전트 초기화
model = PPO("MlpPolicy", vec_env, verbose=1, device="cuda")
# Out:
# Using cuda device

# %%
# 환경 초기화 및 평가
obs = vec_env.reset()
portfolio_values = []

for _ in range(25000):
    action, _states = model.predict(obs)
    obs, rewards, dones, infos = vec_env.step(action)
    # env.unwrapped.save_for_render(dir="render_logs")
    # 포트폴리오 가치 저장 (Key 변경)
    portfolio_values.append(infos[0]['portfolio_valuation'])  # 첫 번째 환경의 포트폴리오 가치 저장

    if dones[0]:
        obs = vec_env.reset()
# Out:
# Market Return : 403.44%   |   Portfolio Return : -98.32%   |

# %%
# 포트폴리오 가치 시각화
plt.figure(figsize=(10, 6))
plt.plot(portfolio_values, label="Portfolio Value")
plt.xlabel('Time Steps')
plt.ylabel('Portfolio Value')
plt.title('Portfolio Value Over Time')
plt.legend()
plt.grid()
plt.show()

# %%
env.unwrapped.save_for_render(dir="render_logs")  # 학습 후 에피소드 결과 저장

from gym_trading_env.renderer import Renderer

# 렌더러 초기화 및 실행
renderer = Renderer(render_logs_dir="render_logs")

# # 시각화에 추가적인 지표 설정 (예시로 SMA 추가)
# renderer.add_line(
#     name="SMA10",
#     function=lambda df: df["close"].rolling(10).mean(),
#     line_options={"width": 1, "color": "purple"}
# )
# 
# renderer.add_line(
#     name="SMA20",
#     function=lambda df: df["close"].rolling(20).mean(),
#     line_options={"width": 1, "color": "blue"}
# )

# 렌더링 시작
renderer.run()
# Out:
#  * Serving Flask app 'gym_trading_env.renderer'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [26/Nov/2024 04:58:41] "GET / HTTP/1.1" 200 -
# [2024-11-26 04:58:43,191] ERROR in app: Exception on /update_data/BTCUSD_2024-11-26_04-58-28.pkl [GET]
# Traceback (most recent call last):
#   File "C:\Users\201910810\anaconda3\Lib\site-packages\flask\app.py", line 2529, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\201910810\anaconda3\Lib\site-packages\flask\app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\201910810\anaconda3\Lib\site-packages\flask\app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\201910810\anaconda3\Lib\site-packages\flask\app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\201910810\anaconda3\Lib\site-packages\gym_trading_env\renderer.py", line 57, in update
#     chart = charts(self.df, self.lines)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\201910810\anaconda3\Lib\site-packages\gym_trading_env\utils\charts.py", line 15, in charts
#     df['date_str'] = df.index.strftime("%Y-%m-%d %H:%M")
#                      ^^^^^^^^^^^^^^^^^
# AttributeError: 'Index' object has no attribute 'strftime'
# 127.0.0.1 - - [26/Nov/2024 04:58:43] "GET /update_data/BTCUSD_2024-11-26_04-58-28.pkl HTTP/1.1" 500 -
# 127.0.0.1 - - [26/Nov/2024 04:58:43] "GET /favicon.ico HTTP/1.1" 404 -

# %%
chart_data, training_data = coin_load_data()
